# %%
import pandas as pd
import seaborn as sns

# %%
fd = pd.read_csv('C:\\Users\\mohamedsobhy\\Desktop\\lec08\\50ulke.csv')

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     float64
#  5   Continent        50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
fd.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
fd.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000189DB881E48>,
# ...
#       dtype=object)

# %%
sns.distplot(fd['National Income'])

# %%
fd['National Income'].hist(bins=30)

# %%
sns.distplot(fd['Growth'])

# %%
fd['Growth'].hist(bins=30)

# %%
fd['Continent'].value_counts()
# Out:
# Asia             19
# Europe           19
# South America     5
# North America     3
# Africa            3
# Oceania           1
# Name: Continent, dtype: int64

# %%
sns.regplot(x=fd['Growth'], y=fd['National Income'])

# %%
sns.jointplot(x=fd['Growth'], y=fd['National Income'])

# %%
sns.kdeplot(fd['Growth'])

# %%
sns.kdeplot(fd['Per person'])

# %%
sns.pairplot(fd)

# %%
sns.pairplot(fd,hue='Continent')
# Out:
# C:\Users\mohamedsobhy\Anaconda3\lib\site-packages\numpy\core\_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\mohamedsobhy\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.boxplot(fd['National Income'])

# %%
sns.boxplot(x=fd['Continent'],y=fd['National Income'],data=fd)

# %%
fd.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27     62152.0
# 1           1           China         14092.51    6.86     10088.0
# 2           2           Japan          5167.05    1.71     40849.0
# 3           3         Germany          4211.64    2.51     50842.0
# 4           4  United Kingdom          2936.29    1.79     44177.0
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
sns.boxplot(x=fd['Continent'],y=fd['Growth'],data=fd)

# %%
sns.boxplot(x=fd['Continent'],y=fd['Per person'],data=fd)

# %%
sns.violinplot(x=fd['Continent'],y=fd['Growth'],data=fd)

# %%
sns.violinplot(x=fd['Continent'],y=fd['Per person'],data=fd)

# %%
sns.boxplot(y=fd['National Income'],data=fd,x=fd['Continent'] , hue=fd['Continent'])

# %%
sns.stripplot(x=fd['Continent'],y=fd['National Income'],data=fd)

# %%
sns.swarmplot(x=fd['Continent'],y=fd['National Income'],data=fd)

# %%
sns.barplot(x=fd['Continent'],y=fd['National Income'],data=fd)

# %%
sns.barplot(x=fd['Continent'],y=fd['Growth'],data=fd)

# %%
fd.corr()
# Out:
#                  Unnamed: 0  National Income    Growth  Per person
# Unnamed: 0         1.000000        -0.549732  0.261063   -0.273373
# National Income   -0.549732         1.000000  0.008961    0.159121
# Growth             0.261063         0.008961  1.000000   -0.252786
# Per person        -0.273373         0.159121 -0.252786    1.000000

# %%
sns.heatmap(fd.corr(),annot=True)

# %%
sns.lmplot(x='Growth',y='National Income',data=fd)
